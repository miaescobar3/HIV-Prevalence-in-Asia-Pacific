# %%
# importting Libraries
import scipy.stats as stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %% [markdown]
# # Education Rate vs HIV Prevalence among SW

# %%
##scatter plot

sns.set_style("darkgrid")

#0= no laws that criminalize HIV transmission   
X1= np.array([47.5, 53]) #Education rate
Y1= np.array([1.6, 2.8]) # Sex Workers HIV prevalence

labels1 = ['India', 'Thailand']

for i, label in enumerate(labels1):
    plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')


#1= there are laws that criminalize HIV transmission

X2= np.array([37.1, 66.8, 25.4, 66.7, 46.8]) #Education Rate
Y2= np.array([3.2, 0, 3.8, 0, 3.1])  # Sex Workers HIV prevalence

labels2 = ['Cambodia', 'Mongolia', 'Pakistan', 'Singapore', 'Vietnam']

plt.text(X2[0], Y2[0], labels2[0])
plt.text(X2[1]+0.1, Y2[1]+0.1, labels2[1])
plt.text(X2[2], Y2[2], labels2[2])
plt.text(X2[3], Y2[3]-0.2, labels2[3])
plt.text(X2[4], Y2[4], labels2[4])

#for i, label in enumerate(labels2):
    #plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')

x = np.concatenate((X1, X2))
y = np.concatenate((Y1, Y2))

# Fit trendline
#m, b = np.polyfit(X1, Y1, 1)

#sns.regplot(x=X1, y=Y1, ci=95, color='green')
#sns.regplot(x=X2, y=Y2, ci=95, color='red')

sns.regplot(x=x, y=y, ci=95, color='blue')


# Calculate the confidence interval
#n = len(x)
#t = stats.t.ppf(0.95, n-2) # 95% confidence interval
#std_dev = np.std(x, ddof=1)
#std_error = std_dev / np.sqrt(n)
ci = t * std_error * np.sqrt(1/n + (x - np.mean(x))**2 / np.sum((x - np.mean(x))**2))

#calculate equation for trendline
#z = np.polyfit(X1, Y1, 1)
#p = np.poly1d(z)

#add trendline to plot
#plt.plot(x, p(x), "blue")

#Overlay
X1= np.array([47.5, 53]) #Education rate
Y1= np.array([1.6, 2.8]) # Sex Workers HIV prevalence

labels1 = ['India', 'Thailand']

for i, label in enumerate(labels1):
    plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

X2= np.array([37.1, 66.8, 25.4, 66.7, 46.8]) #Education Rate
Y2= np.array([3.2, 0, 3.8, 0, 3.1])  # Sex Workers HIV prevalence

labels2 = ['Cambodia', 'Mongolia', 'Pakistan', 'Singapore', 'Vietnam']

#for i, label in enumerate(labels2):
    #plt.text(X2[i], Y2[i], label)

plt.text(X2[0], Y2[0], labels2[0])
plt.text(X2[1]+0.1, Y2[1]+0.1, labels2[1])
plt.text(X2[2], Y2[2], labels2[2])
plt.text(X2[3], Y2[3]-0.2, labels2[3])
plt.text(X2[4], Y2[4], labels2[4])

scatter = plt.scatter(X2, Y2, c='red')

plt.legend(['No','Yes'],loc='upper right', title='Has Laws Criminalizing HIV \n(Transmission, Non-Disclosure, \n or Exposure)', fontsize=10)
plt.title('Relationship Between Education Rates of Young Women and \nHIV Prevalence Among Sex Workers in the Asia Pacific (2021)')
plt.ylabel('HIV Prevalence Among Sex Workers \n(Percentage of Positive tests), UNAIDS', fontsize=10)
plt.xlabel('Participation rate in education and training in the previous 12 months \n (% of female aged 15-24), SDG Gateway', fontsize=10)

#plt.colorbar(scatter)
plt.savefig('Education vs Sex Worker HIV Prevalence.png', bbox_inches='tight', dpi=500)
plt.show()
#print(ci)

# %% [markdown]
# # Healthcare vs HIV Prevalence among PWID

# %%
##scatter plot


#0= no laws that criminalize HIV transmission   
X1= np.array([87, 63, 52]) #Universal Healthcare Coverage Index
Y1= np.array([1.7, 6.3, 19]) # People who inject drugs HIV prevalence

labels1 = ['Australia', 'India', 'Myanmar']

#for i, label in enumerate(labels1):
    #plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

plt.text(X1[0], Y1[0]+0.7, labels1[0])
plt.text(X1[1], Y1[1], labels1[1])
plt.text(X1[2], Y1[2], labels1[2])


#1= there are laws that criminalize HIV transmission

X2= np.array([55, 76, 65, 54, 45, 89, 68, 58, 81]) #Universal Healthcare Coverage Index
Y2= np.array([13.7, 13.5, 0, 2.7, 21, 1.5, 12.7, 15.2, 4.8]) # People who inject drugs HIV prevalence

labels2 = ['Indonesia', 'Malaysia', 'Mongolia', 'Nepal', 'Pakistan', 'Singapore', 'Vietnam', 'Cambodia', 'China']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')

x = np.concatenate((X1, X2))
y = np.concatenate((Y1, Y2))

# Fit trendline
#m, b = np.polyfit(x, y, 1)

#sns.regplot(x=x, y=y, ci=95, color='blue')

#sns.regplot(x=X1, y=Y1, ci=95, color='green')
#sns.regplot(x=X2, y=Y2, ci=95, color='red')

#sns.regplot(x=x, y=y, ci=95, color='blue')

# Calculate the confidence interval
n = len(x)
t = stats.t.ppf(0.95, n-2) # 95% confidence interval
std_dev = np.std(x, ddof=1)
std_error = std_dev / np.sqrt(n)
ci = t * std_error * np.sqrt(1/n + (x - np.mean(x))**2 / np.sum((x - np.mean(x))**2))

#calculate equation for trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

#add trendline to plot
#plt.plot(x, p(x), "blue")


sns.regplot(x=x, y=y, ci=95, color='blue')

#Overlay
X1= np.array([87, 63, 52]) #Universal Healthcare Coverage Index
Y1= np.array([1.7, 6.3, 19]) # People who inject drugs HIV prevalence

labels1 = ['Australia', 'India', 'Myanmar']

#for i, label in enumerate(labels1):
    #plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

plt.text(X1[0], Y1[0]+0.7, labels1[0])
plt.text(X1[1], Y1[1], labels1[1])
plt.text(X1[2], Y1[2], labels1[2])


X2= np.array([55, 76, 65, 54, 45, 89, 68, 58, 81]) #Universal Healthcare Coverage Index
Y2= np.array([13.7, 13.5, 0, 2.7, 21, 1.5, 12.7, 15.2, 4.8]) # People who inject drugs HIV prevalence

labels2 = ['Indonesia', 'Malaysia', 'Mongolia', 'Nepal', 'Pakistan', 'Singapore', 'Vietnam', 'Cambodia', 'China']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')

plt.legend(['No','Yes'],loc='upper right', title='Has Laws Criminalizing HIV \n(Transmission, Non-Disclosure, \n or Exposure)', fontsize=10)
plt.title('Relationship Between Universal Healthcare and HIV Prevalence \nAmong People Who Inject Drugs in the Asia Pacific Region 2021')
plt.ylabel('HIV Prevalence Among People Who Inject Drugs \n(Percentage of Positive tests), UNAIDS', fontsize=10)
plt.xlabel('Universal Health Coverage (Service Coverage Index), SDG Gateway', fontsize=10)

#plt.colorbar(scatter)
plt.savefig('Healthcare vs PWID HIV Prevalence.png', bbox_inches='tight', dpi=500)
plt.show()

# %% [markdown]
# # Education rate vs HIV Prevalence PWID

# %%
##scatter plot

#0= no laws that criminalize HIV transmission 

X1= np.array([65.8, 47.5]) #Participation rate in education and training in the previous 12 months
Y1= np.array([1.7, 6.3]) #People who inject drugs HIV prevalence UNAIDS

labels1 = ['Australia', 'India']

#for i, label in enumerate(labels1):
    #plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

plt.text(X1[0]-0.2, Y1[0]+0.6, labels1[0])
plt.text(X1[1], Y1[1], labels1[1])

#1= there are laws that criminalize HIV transmission   

X2= np.array([48.7, 66.8, 25.4, 66.7, 46.8, 37.1]) #Participation rate in education and training in the previous 12 months
Y2= np.array([13.7, 0, 21, 1.5, 12.7, 15.2]) #People who inject drugs HIV prevalence UNAIDS

labels2 = ['Indonesia', 'Mongolia', 'Pakistan', 'Singapore', 'Vietnam', 'Cambodia']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')

x = np.concatenate((X1, X2))
y = np.concatenate((Y1, Y2))

# Fit trendline
m, b = np.polyfit(x, y, 1)

sns.regplot(x=x, y=y, ci=95, color='blue')

# Calculate the confidence interval
n = len(x)
t = stats.t.ppf(0.95, n-2) # 95% confidence interval
std_dev = np.std(x, ddof=1)
std_error = std_dev / np.sqrt(n)
ci = t * std_error * np.sqrt(1/n + (x - np.mean(x))**2 / np.sum((x - np.mean(x))**2))

#calculate equation for trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

#add trendline to plot
plt.plot(x, p(x), "blue")

#overlay
X1= np.array([65.8, 47.5]) #Participation rate in education and training in the previous 12 months
Y1= np.array([1.7, 6.3]) #People who inject drugs HIV prevalence UNAIDS

labels1 = ['Australia', 'India']

#for i, label in enumerate(labels1):
    #plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

plt.text(X1[0]-0.2, Y1[0]+0.6, labels1[0])
plt.text(X1[1], Y1[1], labels1[1])

labels2 = ['Indonesia', 'Mongolia', 'Pakistan', 'Singapore', 'Vietnam', 'Cambodia']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')

plt.legend(['No','Yes'],loc='upper right', title='Has Laws Criminalizing HIV \n(Transmission, Non-Disclosure, \n or Exposure)', fontsize=10)

plt.title('Relationship Between Education Rates of Young Women and \nHIV Prevalence Among People Who Inject Drugs in the Asia Pacific (2021)')
plt.ylabel('HIV Prevalence Among People Who Inject Drugs \n(percentage of positive tests), UNAIDS', fontsize=10)
plt.xlabel('Participation rate in formal and nonformal education and training in the previous 12 months \n (% of female aged 15-24), SDG Gateway', fontsize=10)

#plt.colorbar(scatter)

plt.savefig('Education vs PWID HIV Prevalence.png', bbox_inches='tight', dpi=500)

plt.show()

# %% [markdown]
# # Healthcare vs HIV Prevalence among SW

# %%
##scatter plot

#0= no laws that criminalize HIV transmission 

X1= np.array([67, 82, 63, 52]) #Universal health coverage, service coverage index (Index)
Y1= np.array([0.3, 2.8, 1.6, 8.3]) #sex workers HIV prevalence UNAIDS

labels1 = ['Sri Lanka', 'Thailand', 'India', 'Myanmar']

for i, label in enumerate(labels1):
    plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

#1= there are laws that criminalize HIV transmission   

X2= np.array([58, 81, 55, 52, 76, 65, 54, 45, 30, 55, 89, 68]) #Universal health coverage, service coverage index (Index)
Y2= np.array([3.2, 9.2, 2.1, 0.8, 6.3, 0, 4.2, 3.8, 15.5, 0, 0, 3.1]) #sex workers HIV prevalence UNAIDS

labels2 = ['Cambodia', 'China', 'Indonesia', 'Laos', 'Malaysia', 'Mongolia', 'Nepal', 'Pakistan', 'Papa New Guinea', 'Samoa', 'Singapore', 'Vietnam']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')

x = np.concatenate((X1, X2))
y = np.concatenate((Y1, Y2))

# Fit trendline
m, b = np.polyfit(x, y, 1)

sns.regplot(x=x, y=y, ci= 95, color='blue')

# Calculate the confidence interval
n = len(x)
t = stats.t.ppf(0.95, n-2) # 95% confidence interval
std_dev = np.std(x, ddof=1)
std_error = std_dev / np.sqrt(n)
ci = t * std_error * np.sqrt(1/n + (x - np.mean(x))**2 / np.sum((x - np.mean(x))**2))

#calculate equation for trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

#add trendline to plot
plt.plot(x, p(x), "blue")

#overlay
X1= np.array([67, 82, 63, 52]) #Universal health coverage, service coverage index (Index)
Y1= np.array([0.3, 2.8, 1.6, 8.3]) #sex workers HIV prevalence UNAIDS

labels1 = ['Sri Lanka', 'Thailand', 'India', 'Myanmar']

for i, label in enumerate(labels1):
    plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

X2= np.array([58, 81, 55, 52, 76, 65, 54, 45, 30, 55, 89, 68]) #Universal health coverage, service coverage index (Index)
Y2= np.array([3.2, 9.2, 2.1, 0.8, 6.3, 0, 4.2, 3.8, 15.5, 0, 0, 3.1]) #sex workers HIV prevalence UNAIDS

labels2 = ['Cambodia', 'China', 'Indonesia', 'Laos', 'Malaysia', 'Mongolia', 'Nepal', 'Pakistan', 'Papa New Guinea', 'Samoa', 'Singapore', 'Vietnam']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')


plt.legend(['No','Yes'],loc='upper right', title='Has Laws Criminalizing HIV \n(Transmission, Non-Disclosure, \n or Exposure)', fontsize=10)

plt.title('Relationship Between Universal Healthcare and HIV Prevalence \nAmong Sex Workers in the Asia Pacific Region 2021')
plt.ylabel('HIV Prevalence Among Sex Workers (Percentage of \nPositive Tests), UNAIDS', fontsize=10)
plt.xlabel('Universal Health Coverage (Service Coverage Index), SDG Gateway', fontsize=10)

#plt.colorbar(scatter)

plt.savefig('Healthcare vs Sex Worker HIV Prevalence.png', bbox_inches='tight', dpi=500)

plt.show()

# %% [markdown]
# # Healthcare vs HIV Prevalence Among Prisoners

# %%
##scatter plot

#0= no laws that criminalize HIV transmission 

X1= np.array([67, 82, 63, 52]) #Universal health coverage, service coverage index (Index)
Y1= np.array([0, 0.9, 2.1, 4.7]) #PR HIV prevalence UNAIDS

labels1 = ['Sri Lanka', 'Thailand', 'India', 'Myanmar']

#for i, label in enumerate(labels1):
    #plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')\

plt.text(X1[0], Y1[0]-0.3, labels1[0])
plt.text(X1[1]+0.1, Y1[1]+0.1, labels1[1])
plt.text(X1[2], Y1[2], labels1[2])
plt.text(X1[3], Y1[3]-0.2, labels1[3])

#1= there are laws that criminalize HIV transmission   

X2= np.array([78, 55, 76, 65, 45, 89]) #Universal health coverage, service coverage index (Index)
Y2= np.array([0.9, 0.7, 0.2, 0, 2, 1.1]) #PR HIV prevalence UNAIDS

labels2 = ['Brunei', 'Indonesia', 'Malaysia', 'Mongolia', 'Pakistan', 'Singapore']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')

x = np.concatenate((X1, X2))
y = np.concatenate((Y1, Y2))

# Fit trendline
m, b = np.polyfit(x, y, 1)

sns.regplot(x=x, y=y, ci= 95, color='blue')

# Calculate the confidence interval
n = len(x)
t = stats.t.ppf(0.95, n-2) # 95% confidence interval
std_dev = np.std(x, ddof=1)
std_error = std_dev / np.sqrt(n)
ci = t * std_error * np.sqrt(1/n + (x - np.mean(x))**2 / np.sum((x - np.mean(x))**2))

#calculate equation for trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

#add trendline to plot
plt.plot(x, p(x), "blue")

#overlay
#0= no laws that criminalize HIV transmission 

X1= np.array([67, 82, 63, 52]) #Universal health coverage, service coverage index (Index)
Y1= np.array([0, 0.9, 2.1, 4.7]) #PR HIV prevalence UNAIDS

labels1 = ['Sri Lanka', 'Thailand', 'India', 'Myanmar']

#for i, label in enumerate(labels1):
   # plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

plt.text(X1[0], Y1[0]-0.3, labels1[0])
plt.text(X1[1]+0.1, Y1[1]+0.1, labels1[1])
plt.text(X1[2], Y1[2], labels1[2])
plt.text(X1[3], Y1[3]-0.2, labels1[3])

#1= there are laws that criminalize HIV transmission   

X2= np.array([78, 55, 76, 65, 45, 89]) #Universal health coverage, service coverage index (Index)
Y2= np.array([0.9, 0.7, 0.2, 0, 2, 1.1]) #PR HIV prevalence UNAIDS

labels2 = ['Brunei', 'Indonesia', 'Malaysia', 'Mongolia', 'Pakistan', 'Singapore']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')


plt.legend(['No','Yes'],loc='upper right', title='Has Laws Criminalizing HIV \n(Transmission, Non-Disclosure, \n or Exposure)', fontsize=10)

plt.title('Relationship Between Universal Healthcare and HIV Prevalence \nAmong Prisoners in the Asia Pacific Region 2021')
plt.ylabel('HIV Prevalence Among Prisoners (Percentage of Positive Tests), \nUNAIDS', fontsize=10)
plt.xlabel('Universal Health Coverage (Service Coverage Index), SDG Gateway', fontsize=10)

#plt.colorbar(scatter)

plt.savefig('Healthcare vs Prisoner HIV Prevalence.png', bbox_inches='tight', dpi=500)

plt.show()

# %% [markdown]
# # Education vs HIV Prevalence Among Prisoners

# %%
##scatter plot

#0= no laws that criminalize HIV transmission 

X1= np.array([53, 47.5]) #% of females (15-24) participating in formal and nonformal education (previous 12 months)
Y1= np.array([0.9, 2.1]) #Prisoner HIV prevalence UNAIDS

labels1 = ['Thailand', 'India']

for i, label in enumerate(labels1):
    plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

#1= there are laws that criminalize HIV transmission   

X2= np.array([58.2, 48.7, 66.8, 25.4, 66.7]) #% of females (15-24) participating in formal and nonformal education (previous 12 months)
Y2= np.array([0.9, 0.7, 0, 2, 1.1]) #Prisoner HIV prevalence UNAIDS

labels2 = ['Brunei', 'Indonesia', 'Mongolia', 'Pakistan', 'Singapore']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')

x = np.concatenate((X1, X2))
y = np.concatenate((Y1, Y2))

# Fit trendline
m, b = np.polyfit(x, y, 1)

sns.regplot(x=x, y=y, ci=95, color='blue')

# Calculate the confidence interval
n = len(x)
t = stats.t.ppf(0.95, n-2) # 95% confidence interval
std_dev = np.std(x, ddof=1)
std_error = std_dev / np.sqrt(n)
ci = t * std_error * np.sqrt(1/n + (x - np.mean(x))**2 / np.sum((x - np.mean(x))**2))

#calculate equation for trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

#add trendline to plot
plt.plot(x, p(x), "blue")

#overlay

X1= np.array([53, 47.5]) #% of females (15-24) participating in formal and nonformal education (previous 12 months)
Y1= np.array([0.9, 2.1]) #Prisoner HIV prevalence UNAIDS

labels1 = ['Thailand', 'India']

for i, label in enumerate(labels1):
    plt.text(X1[i], Y1[i], label)
plt.scatter(X1, Y1, c='green')

#1= there are laws that criminalize HIV transmission   

X2= np.array([58.2, 48.7, 66.8, 25.4, 66.7]) #% of females (15-24) participating in formal and nonformal education (previous 12 months)
Y2= np.array([0.9, 0.7, 0, 2, 1.1]) #Prisoner HIV prevalence UNAIDS

labels2 = ['Brunei', 'Indonesia', 'Mongolia', 'Pakistan', 'Singapore']

for i, label in enumerate(labels2):
    plt.text(X2[i], Y2[i], label)

scatter = plt.scatter(X2, Y2, c='red')


plt.legend(['No','Yes'],loc='upper right', title='Has Laws Criminalizing HIV \n(Transmission, Non-Disclosure, \n or Exposure)', fontsize=10)

plt.title('Relationship Between Education Rates of Young Women and \nHIV Prevalence Among Prisoners in the Asia Pacific (2021)')
plt.ylabel('HIV Prevalence Among Prisoners (Percentage of Positive Tests), \nUNAIDS', fontsize=10)
plt.xlabel('Participation rate in education and training in the previous 12 months \n (% of female aged 15-24), SDG Gateway', fontsize=10)

#plt.colorbar(scatter)

plt.savefig('Education vs Prisoner HIV Prevalence.png', bbox_inches='tight', dpi=500)

plt.show()
