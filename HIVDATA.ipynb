# %%
# importting Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
# loading and reading dataset
df = pd.read_csv("HIVdata.csv")
# shape of the data
df.shape
#data information 
df.info()
# describing the data
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 12 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Countries                                                                       37 non-null     object
#  1   New Infections 2023 (UNAIDS)                                                    20 non-null     float64
#  2   Number of people living with HIV (2023)                                         22 non-null     float64
#  3   GDP per capita (IMF)                                                            35 non-null     float64
#  4   sex workers (HIV prevalence most recent data as of 2023, UNAIDS)                13 non-null     float64
#  5   men who have sex with men (HIV prevalence most recent data as of 2023, UNAIDS)  14 non-null     float64
# ...

# %%
# check for missing values:
df.isnull().sum()
# Out:
# Countries                                                                          0
# New Infections 2023 (UNAIDS)                                                      17
# Number of people living with HIV (2023)                                           15
# GDP per capita (IMF)                                                               2
# sex workers (HIV prevalence most recent data as of 2023, UNAIDS)                  24
# men who have sex with men (HIV prevalence most recent data as of 2023, UNAIDS)    23
# Injecting drugs (HIV prevalence most recent data as of 2023, UNAIDS)              28
# Prisoners (HIV prevalence most recent data as of 2023, UNAIDS)                    26
# Transgender (HIV prevalence most recent data as of 2023, UNAIDS)                  28
# adolencent women with HIV 2023 ( UNAIDS)                                          16
# HIV expendature 2023                                                              26
# ...

# %%
# Set Seaborn style
sns.set_style("darkgrid")

# Identify numerical columns
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns

# Plot distribution of each numerical feature
plt.figure(figsize=(14, len(numerical_columns) * 3))
for idx, feature in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 2, idx)
    sns.histplot(df[feature], kde=True)
    plt.title(f"{feature} | Skewness: {round(df[feature].skew(), 2)}")

# Adjust layout and show plots
plt.tight_layout()
plt.show()

# %%
# Assuming 'df' is your DataFrame
plt.figure(figsize=(10, 8))

# Using Seaborn to create a swarm plot
sns.swarmplot(x="Co-management of TB and HIV treatment (2023)", y="New Infections 2023 (UNAIDS)", data=df, palette='viridis')

plt.title('Swarm Plot')
plt.xlabel('Co-management of TB and HIV treatment (2023)')
plt.ylabel('New Infections 2023 (UNAIDS)')
plt.show()

# %%
# Set the color palette
sns.set_palette("Pastel1")

# Assuming 'df' is your DataFrame
plt.figure(figsize=(10, 6))

# Using Seaborn to create a pair plot with the specified color palette
sns.pairplot(df)

plt.suptitle('Pair Plot for DataFrame')
plt.show()

# %%
#correlation matrix
df2 = pd.read_csv("HIVdata.csv", usecols=["New Infections 2023 (UNAIDS)", "Number of people living with HIV (2023)", "GDP per capita (IMF)", "sex workers (HIV prevalence most recent data as of 2023, UNAIDS)", "men who have sex with men (HIV prevalence most recent data as of 2023, UNAIDS)", "Injecting drugs (HIV prevalence most recent data as of 2023, UNAIDS)", "Prisoners (HIV prevalence most recent data as of 2023, UNAIDS)", "Transgender (HIV prevalence most recent data as of 2023, UNAIDS)", "adolencent women with HIV 2023 ( UNAIDS)", "HIV expendature 2023", "Co-management of TB and HIV treatment (2023)"])

matrix = df2

# %%
# Assuming 'df' is your DataFrame
plt.figure(figsize=(15, 10))

# Using Seaborn to create a heatmap
sns.heatmap(matrix.corr(), annot=True, fmt='.2f', cmap='Blues', linewidths=2)

plt.title('Correlation Heatmap')
plt.show()
